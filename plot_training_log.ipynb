# %%
# %matplotlib notebook

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set()

# %%
filename = 'unet_ds_low_patch0_fold1_dice0_training.log'

# %%
data = pd.read_table(filename, names=['epoch', 'set','bce','dice','total'])

# %%
data.head()
# Out:
#    epoch    set    bce   dice  total
# 0      0  train  0.739  0.590  0.739
# 1      0    val  0.675  0.607  0.675
# 2      1  train  0.545  0.481  0.545
# 3      1    val  0.605  0.656  0.605
# 4      2  train  0.514  0.437  0.514

# %%
pd.pivot_table(data, values='bce', index='epoch', columns='set').val.min()
# Out:
# 0.13200000000000001

# %%
1 - pd.pivot_table(data, values='dice', index='epoch', columns='set').val.min()
# Out:
# 0.84199999999999997

# %%
data_grouped = pd.pivot_table(data, values='bce', index='epoch', columns='set')

# %%
data_grouped.plot(ylim=[0,1.0])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# 0.187
