# %%
# %matplotlib notebook

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set()

# %%
filename = 'training.log'

# %%
data = pd.read_table(filename, names=['epoch', 'set','bce','dice','total'])

# %%
data.head()
# Out:
#    epoch    set    bce   dice  total
# 0      0  train  0.529  0.448  0.529
# 1      0    val  0.485  0.369  0.485
# 2      1  train  0.453  0.390  0.453
# 3      1    val  0.476  0.363  0.476
# 4      2  train  0.430  0.376  0.430

# %%
data_grouped = pd.pivot_table(data, values='dice', index='epoch', columns='set')

# %%
data_grouped.plot(ylim=[0,1.0])
# Out:
# <img src="data:image/png;base64,..." width="640">
