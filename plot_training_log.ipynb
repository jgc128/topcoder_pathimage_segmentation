# %%
# %matplotlib notebook

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set()

# %%
filename = 'training.log'

# %%
data = pd.read_table(filename, names=['epoch', 'set','bce','dice','total'])

# %%
data.head()
# Out:
#    epoch    set    bce   dice  total
# 0      0  train  0.571  0.477  0.571
# 1      0    val  0.470  0.452  0.470
# 2      1  train  0.465  0.401  0.465
# 3      1    val  0.555  0.381  0.555
# 4      2  train  0.441  0.386  0.441

# %%
data_grouped = pd.pivot_table(data, values='dice', index='epoch', columns='set')

# %%
data_grouped.plot(ylim=[0,1.0])
# Out:
# <img src="data:image/png;base64,..." width="640">
